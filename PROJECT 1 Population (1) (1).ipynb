# %% [markdown]
# # PANDAS

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# # population project

# %%
df = pd.DataFrame({
    
                'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
         9525067],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
     },
columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index=['Canada','France','Germany','Italy','Japan','Uk','US']  
print(df)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df['Population'] # find population only
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Uk          64.511
# US         318.523
# Name: Population, dtype: float64

# %%
df[['Population','GDP']] # use 2 list
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# Uk           64.511   2950039
# US          318.523  17348075

# %% [markdown]
# ## loc and iloc

# %%
# loc= index name only
# iloc (index number)

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[[0,3,1]]
# Out:
#         Population      GDP  Surface Area    HDI Continent
# Canada      35.467  1785387       9984670  0.913   America
# Italy       60.665  2167744        301336  0.873    Europe
# France      63.951  2833687        640679  0.888    Europe

# %%
df.loc[['France','Germany']] # multiple index use 2 list
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.loc['France':'Japan'] # slicing use character index (include japan)
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia

# %%
df.iloc[0:5] # slicing use integer (not include 5th index)
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia

# %%
df.loc['France':'Italy','Population'] # france to italy population only
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc[['France','Italy'],['Population','GDP']] # index of france and italy population and GDP only
# Out:
#         Population      GDP
# France      63.951  2833687
# Italy       60.665  2167744

# %%
df.iloc[[0,1,-1,-2]] # indeger index 0 and one last index -1,-2
# Out:
#         Population       GDP  Surface Area    HDI Continent
# Canada      35.467   1785387       9984670  0.913   America
# France      63.951   2833687        640679  0.888    Europe
# US         318.523  17348075       9525067  0.915   America
# Uk          64.511   2950039        242495  0.907    Europe

# %% [markdown]
# ## conditional selectin (boolean arrays)

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df['Population']>70
# Out:
# Canada     False
# France     False
# Germany     True
# Italy      False
# Japan       True
# Uk         False
# US          True
# Name: Population, dtype: bool

# %%
df[df['Population']>70]
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# US          318.523  17348075       9525067  0.915   America

# %%
df.loc[df['Population']>70,'Population']
# Out:
# Germany     80.940
# Japan      127.061
# US         318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population']>70,['Population','GDP']]
# Out:
#          Population       GDP
# Germany      80.940   3874437
# Japan       127.061   4602367
# US          318.523  17348075

# %% [markdown]
# ## Data exploration and cleaning

# %%
df.columns # to know how many columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index # find index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'Uk', 'US'], dtype='object')

# %%
df.info() # find all informtion about the dataframe(colums,have any null values,dtype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to US
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
df.shape # 7 raw, 5 columns
# Out:
# (7, 5)

# %%
df.size # 7*5=35
# Out:
# 35

# %%
df.dtypes # find datatype
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %% [markdown]
# #### TO know about statistical informations

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.describe(include='all')
# Out:
#         Population           GDP  Surface Area       HDI Continent
# count     7.000000  7.000000e+00  7.000000e+00  7.000000         7
# unique         NaN           NaN           NaN       NaN         3
# top            NaN           NaN           NaN       NaN    Europe
# freq           NaN           NaN           NaN       NaN         4
# mean    107.302571  5.080248e+06  3.061327e+06  0.900429       NaN
# std      97.249970  5.494020e+06  4.576187e+06  0.016592       NaN
# min      35.467000  1.785387e+06  2.424950e+05  0.873000       NaN
# 25%      62.308000  2.500716e+06  3.292250e+05  0.889500       NaN
# 50%      64.511000  2.950039e+06  3.779300e+05  0.907000       NaN
# 75%     104.000500  4.238402e+06  5.082873e+06  0.914000       NaN
# max     318.523000  1.734808e+07  9.984670e+06  0.916000       NaN

# %%
df['Continent'].value_counts() # count continent values
# Out:
# Continent
# Europe     4
# America    2
# Asia       1
# Name: count, dtype: int64

# %%
df.dtypes.value_counts() # count data type values
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %%
df.head() # this print first 5 datas
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia

# %%
df.head(6)
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia
# Uk           64.511  2950039        242495  0.907    Europe

# %%
df.tail() # it print last 5 data
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.tail(7)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.sort_values(by='Population',ascending=False) # to sort data use population ,ascendind=False(descending order)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# US          318.523  17348075       9525067  0.915   America
# Japan       127.061   4602367        377930  0.891      Asia
# Germany      80.940   3874437        357114  0.916    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# France       63.951   2833687        640679  0.888    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Canada       35.467   1785387       9984670  0.913   America

# %%
df.sort_values(by="Population",ascending=True) # its sort data ascending order
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# Italy        60.665   2167744        301336  0.873    Europe
# France       63.951   2833687        640679  0.888    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# US          318.523  17348075       9525067  0.915   America

# %%
df.sort_values(by="Continent",ascending=True)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# US          318.523  17348075       9525067  0.915   America
# Japan       127.061   4602367        377930  0.891      Asia
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Uk           64.511   2950039        242495  0.907    Europe

# %%
df.sort_values(by="Continent",ascending=False)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Canada       35.467   1785387       9984670  0.913   America
# US          318.523  17348075       9525067  0.915   America

# %%
new_df=df.drop('Canada') # erise canada and its details
new_df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
new=df.drop(['Canada', 'Japan'])
new
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
new=df.drop(columns=['Population', 'HDI']) # remove columns population and hdi
new
# Out:
#               GDP  Surface Area Continent
# Canada    1785387       9984670   America
# France    2833687        640679    Europe
# Germany   3874437        357114    Europe
# Italy     2167744        301336    Europe
# Japan     4602367        377930      Asia
# Uk        2950039        242495    Europe
# US       17348075       9525067   America

# %%
new=df.drop(['Italy', 'Canada'], axis=0) # axis=0 raw
new
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
new=df.drop(['Population', 'HDI'], axis=1) # axis=1 column
new
# Out:
#               GDP  Surface Area Continent
# Canada    1785387       9984670   America
# France    2833687        640679    Europe
# Germany   3874437        357114    Europe
# Italy     2167744        301336    Europe
# Japan     4602367        377930      Asia
# Uk        2950039        242495    Europe
# US       17348075       9525067   America

# %%
new=df.drop(['Population', 'HDI'], axis='columns') # other way axis=1
new
# Out:
#               GDP  Surface Area Continent
# Canada    1785387       9984670   America
# France    2833687        640679    Europe
# Germany   3874437        357114    Europe
# Italy     2167744        301336    Europe
# Japan     4602367        377930      Asia
# Uk        2950039        242495    Europe
# US       17348075       9525067   America

# %%
df1=df # change the name
df1
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
 #df.drop(columns='Population', inplace=True) # remove data permenantly
#All these drop methods return a new DataFrame. If you'd like to modify it "in place", you can use the inplace attribute (there's an example below).

# %% [markdown]
# ## Data Cleaning
# ## dropna(), fillna(), isnull()

# %%
df.dropna()# remove null values
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df[['Population', 'GDP']]
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# Uk           64.511   2950039
# US          318.523  17348075

# %%
df[['Population', 'GDP']] / 100 # percentage
# Out:
#          Population        GDP
# Canada      0.35467   17853.87
# France      0.63951   28336.87
# Germany     0.80940   38744.37
# Italy       0.60665   21677.44
# Japan       1.27061   46023.67
# Uk          0.64511   29500.39
# US          3.18523  173480.75

# %%
df[ 'GDP'] / 100
# Out:
# Canada      17853.87
# France      28336.87
# Germany     38744.37
# Italy       21677.44
# Japan       46023.67
# Uk          29500.39
# US         173480.75
# Name: GDP, dtype: float64

# %% [markdown]
# #### how to add a new raw

# %%
crisis = pd.Series([-1_000_000,-0.3], index=['GDP', 'HDI']) # add this value in all raw of gdp and hbi
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']] # crisis added gdp and hdi
# Out:
#               GDP    HDI
# Canada    1785387  0.913
# France    2833687  0.888
# Germany   3874437  0.916
# Italy     2167744  0.873
# Japan     4602367  0.891
# Uk        2950039  0.907
# US       17348075  0.915

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                 GDP    HDI
# Canada     785387.0  0.613
# France    1833687.0  0.588
# Germany   2874437.0  0.616
# Italy     1167744.0  0.573
# Japan     3602367.0  0.591
# Uk        1950039.0  0.607
# US       16348075.0  0.615

# %%
df # crisis added data frame
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## how to add a new column

# %%
langs=pd.Series(['french','italian','german'],
                index=['France','Italy','Germany'],
                name='Languages')

df['Languages']=langs

df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN

# %%
df.isnull().sum() # print null values details
# Out:
# Population      0
# GDP             0
# Surface Area    0
# HDI             0
# Continent       0
# Languages       4
# dtype: int64

# %%
df.dropna() # remove null values
# Out:
#          Population      GDP  Surface Area    HDI Continent Languages
# France       63.951  2833687        640679  0.888    Europe    french
# Germany      80.940  3874437        357114  0.916    Europe    german
# Italy        60.665  2167744        301336  0.873    Europe   italian

# %%
df.fillna("English") # fill english in all null spaces
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages
# Canada       35.467   1785387       9984670  0.913   America   English
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia   English
# Uk           64.511   2950039        242495  0.907    Europe   English
# US          318.523  17348075       9525067  0.915   America   English

# %% [markdown]
# ### replacing values per column

# %%
df['Language'] = 'English'
df['Language']=df['Language'].replace(['English'],'French')
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages  \
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN
#
#         Language
# Canada    French
# France    French
# Germany   French
# Italy     French
# Japan     French
# Uk        French
# US        French

# %%
df['Language']=df['Language'].replace(['French'],'English')
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages  \
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN
#
#         Language
# Canada   English
# France   English
# Germany  English
# Italy    English
# Japan    English
# Uk       English
# US       English

# %%
df = pd.DataFrame({
    
                'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
         9525067],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
     }, 
 columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])
df.index=['Canada','France','Germany','Italy','Japan','Uk','US']          
print(df)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df['Population']
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Uk          64.511
# US         318.523
# Name: Population, dtype: float64

# %%
df[['Population','GDP']]
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# Uk           64.511   2950039
# US          318.523  17348075

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.loc[['France','Italy']]
# Out:
#         Population      GDP  Surface Area    HDI Continent
# France      63.951  2833687        640679  0.888    Europe
# Italy       60.665  2167744        301336  0.873    Europe

# %%
df.iloc[1]
# Out:
# Population       63.951
# GDP             2833687
# Surface Area     640679
# HDI               0.888
# Continent        Europe
# Name: France, dtype: object

# %%
df.iloc[[0,1,2]]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.loc['Canada':'Uk']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia
# Uk           64.511  2950039        242495  0.907    Europe

# %%
df.iloc[1:6]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia
# Uk           64.511  2950039        242495  0.907    Europe

# %%
df.loc['France':'Japan','Population']
# Out:
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Name: Population, dtype: float64

# %%
df.loc[['Germany','Uk'],['Population','Continent']]
# Out:
#          Population Continent
# Germany      80.940    Europe
# Uk           64.511    Europe

# %%
df.iloc[[1,2,-1,-2]]
# Out:
#          Population       GDP  Surface Area    HDI Continent
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# US          318.523  17348075       9525067  0.915   America
# Uk           64.511   2950039        242495  0.907    Europe

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df['Population']>70
# Out:
# Canada     False
# France     False
# Germany     True
# Italy      False
# Japan       True
# Uk         False
# US          True
# Name: Population, dtype: bool

# %%
df[df['Population']>70]
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# US          318.523  17348075       9525067  0.915   America

# %%
df.loc[df['Population']>70,'Population']
# Out:
# Germany     80.940
# Japan      127.061
# US         318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population']>70,['Population','GDP']]
# Out:
#          Population       GDP
# Germany      80.940   3874437
# Japan       127.061   4602367
# US          318.523  17348075

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'Uk', 'US'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to US
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
df.shape
# Out:
# (7, 5)

# %%
df.size
# Out:
# 35

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.describe(include='all')
# Out:
#         Population           GDP  Surface Area       HDI Continent
# count     7.000000  7.000000e+00  7.000000e+00  7.000000         7
# unique         NaN           NaN           NaN       NaN         3
# top            NaN           NaN           NaN       NaN    Europe
# freq           NaN           NaN           NaN       NaN         4
# mean    107.302571  5.080248e+06  3.061327e+06  0.900429       NaN
# std      97.249970  5.494020e+06  4.576187e+06  0.016592       NaN
# min      35.467000  1.785387e+06  2.424950e+05  0.873000       NaN
# 25%      62.308000  2.500716e+06  3.292250e+05  0.889500       NaN
# 50%      64.511000  2.950039e+06  3.779300e+05  0.907000       NaN
# 75%     104.000500  4.238402e+06  5.082873e+06  0.914000       NaN
# max     318.523000  1.734808e+07  9.984670e+06  0.916000       NaN

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Europe     4
# America    2
# Asia       1
# Name: count, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia

# %%
df.head(6)
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe
# Japan       127.061  4602367        377930  0.891      Asia
# Uk           64.511  2950039        242495  0.907    Europe

# %%
df.tail()
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.tail(5)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.sort_values(by="Population",ascending=True)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# Italy        60.665   2167744        301336  0.873    Europe
# France       63.951   2833687        640679  0.888    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# US          318.523  17348075       9525067  0.915   America

# %%
df.sort_values(by="Population",ascending=False)
# Out:
#          Population       GDP  Surface Area    HDI Continent
# US          318.523  17348075       9525067  0.915   America
# Japan       127.061   4602367        377930  0.891      Asia
# Germany      80.940   3874437        357114  0.916    Europe
# Uk           64.511   2950039        242495  0.907    Europe
# France       63.951   2833687        640679  0.888    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Canada       35.467   1785387       9984670  0.913   America

# %%
df.dropna()
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df[['Population','GDP']]/100
# Out:
#          Population        GDP
# Canada      0.35467   17853.87
# France      0.63951   28336.87
# Germany     0.80940   38744.37
# Italy       0.60665   21677.44
# Japan       1.27061   46023.67
# Uk          0.64511   29500.39
# US          3.18523  173480.75

# %%
crisis = pd.Series([-1_000_000,-0.3], index=['GDP', 'HDI']) # add this value in all raw of gdp and hbi
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']]
# Out:
#               GDP    HDI
# Canada    1785387  0.913
# France    2833687  0.888
# Germany   3874437  0.916
# Italy     2167744  0.873
# Japan     4602367  0.891
# Uk        2950039  0.907
# US       17348075  0.915

# %%
df[['GDP','HDI']]+crisis
# Out:
#                 GDP    HDI
# Canada     785387.0  0.613
# France    1833687.0  0.588
# Germany   2874437.0  0.616
# Italy     1167744.0  0.573
# Japan     3602367.0  0.591
# Uk        1950039.0  0.607
# US       16348075.0  0.615

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# Uk           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
langs=pd.Series(['french','italian','german'],
                index=['France','Italy','Germany'],
                name='Languages')

df['Languages']=langs

df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN

# %%
df.isnull().sum() # print null values details
# Out:
# Population      0
# GDP             0
# Surface Area    0
# HDI             0
# Continent       0
# Languages       4
# dtype: int64

# %%
df.fillna("English")
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages
# Canada       35.467   1785387       9984670  0.913   America   English
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia   English
# Uk           64.511   2950039        242495  0.907    Europe   English
# US          318.523  17348075       9525067  0.915   America   English

# %%
df['Language'] = 'English'
df['Language']=df['Language'].replace(['English'],'French')
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages  \
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN
#
#         Language
# Canada    French
# France    French
# Germany   French
# Italy     French
# Japan     French
# Uk        French
# US        French

# %%
df['Language']=df['Language'].replace(['French'],'English')
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Languages  \
# Canada       35.467   1785387       9984670  0.913   America       NaN
# France       63.951   2833687        640679  0.888    Europe    french
# Germany      80.940   3874437        357114  0.916    Europe    german
# Italy        60.665   2167744        301336  0.873    Europe   italian
# Japan       127.061   4602367        377930  0.891      Asia       NaN
# Uk           64.511   2950039        242495  0.907    Europe       NaN
# US          318.523  17348075       9525067  0.915   America       NaN
#
#         Language
# Canada   English
# France   English
# Germany  English
# Italy    English
# Japan    English
# Uk       English
# US       English

# %% [markdown]
# ### renaming column

# %%
df.rename(columns={"Languages":"Lan"},inplace=True) 

df
# Out:
#          Population       GDP  Surface Area    HDI Continent      Lan Language
# Canada       35.467   1785387       9984670  0.913   America      NaN  English
# France       63.951   2833687        640679  0.888    Europe   french  English
# Germany      80.940   3874437        357114  0.916    Europe   german  English
# Italy        60.665   2167744        301336  0.873    Europe  italian  English
# Japan       127.061   4602367        377930  0.891      Asia      NaN  English
# Uk           64.511   2950039        242495  0.907    Europe      NaN  English
# US          318.523  17348075       9525067  0.915   America      NaN  English

# %%
df.rename(columns={'HDI':'Human DEvelopment Index'},
          index={'US':'United states','Uk':'United Kingdom' },inplace=True )
df
# Out:
#                 Population       GDP  Surface Area  Human DEvelopment Index  \
# Canada              35.467   1785387       9984670                    0.913
# France              63.951   2833687        640679                    0.888
# Germany             80.940   3874437        357114                    0.916
# Italy               60.665   2167744        301336                    0.873
# Japan              127.061   4602367        377930                    0.891
# United Kingdom      64.511   2950039        242495                    0.907
# United states      318.523  17348075       9525067                    0.915
#
#                Continent      Lan Language
# Canada           America      NaN  English
# France            Europe   french  English
# Germany           Europe   german  English
# Italy             Europe  italian  English
# Japan               Asia      NaN  English
# United Kingdom    Europe      NaN  English
# United states    America      NaN  English

# %%
df.rename(index=str.upper) # index upper case
# Out:
#                 Population       GDP  Surface Area  Human DEvelopment Index  \
# CANADA              35.467   1785387       9984670                    0.913
# FRANCE              63.951   2833687        640679                    0.888
# GERMANY             80.940   3874437        357114                    0.916
# ITALY               60.665   2167744        301336                    0.873
# JAPAN              127.061   4602367        377930                    0.891
# UNITED KINGDOM      64.511   2950039        242495                    0.907
# UNITED STATES      318.523  17348075       9525067                    0.915
#
#                Continent      Lan Language
# CANADA           America      NaN  English
# FRANCE            Europe   french  English
# GERMANY           Europe   german  English
# ITALY             Europe  italian  English
# JAPAN               Asia      NaN  English
# UNITED KINGDOM    Europe      NaN  English
# UNITED STATES    America      NaN  English

# %%
df.rename(index=str.lower)
# Out:
#                 Population       GDP  Surface Area  Human DEvelopment Index  \
# canada              35.467   1785387       9984670                    0.913
# france              63.951   2833687        640679                    0.888
# germany             80.940   3874437        357114                    0.916
# italy               60.665   2167744        301336                    0.873
# japan              127.061   4602367        377930                    0.891
# united kingdom      64.511   2950039        242495                    0.907
# united states      318.523  17348075       9525067                    0.915
#
#                Continent      Lan Language
# canada           America      NaN  English
# france            Europe   french  English
# germany           Europe   german  English
# italy             Europe  italian  English
# japan               Asia      NaN  English
# united kingdom    Europe      NaN  English
# united states    America      NaN  English

# %%
df.rename(index=lambda x:x.upper()) # make upper case use lambda function
# Out:
#                 Population       GDP  Surface Area  Human DEvelopment Index  \
# CANADA              35.467   1785387       9984670                    0.913
# FRANCE              63.951   2833687        640679                    0.888
# GERMANY             80.940   3874437        357114                    0.916
# ITALY               60.665   2167744        301336                    0.873
# JAPAN              127.061   4602367        377930                    0.891
# UNITED KINGDOM      64.511   2950039        242495                    0.907
# UNITED STATES      318.523  17348075       9525067                    0.915
#
#                Continent      Lan Language
# CANADA           America      NaN  English
# FRANCE            Europe   french  English
# GERMANY           Europe   german  English
# ITALY             Europe  italian  English
# JAPAN               Asia      NaN  English
# UNITED KINGDOM    Europe      NaN  English
# UNITED STATES    America      NaN  English

# %%
df.rename(columns=lambda x:x.upper())
# Out:
#                 POPULATION         GDP  SURFACE AREA  HUMAN DEVELOPMENT INDEX  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                CONTINENT      LAN LANGUAGE  GDP PER CAPITA
# Canada           America      NaN  English    50339.385908
# France            Europe   french  English    44310.284437
# Germany           Europe   german  English    47868.013343
# ...

# %%
df.loc['China']=pd.Series({'Population':500,'Human DEvelopment Index':0.987,'Continent':'Asis','Language':'Chinees'})
df
# Out:
#                 Population         GDP  Surface Area  Human DEvelopment Index  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                Continent      Lan Language
# Canada           America      NaN  English
# France            Europe   french  English
# Germany           Europe   german  English
# Italy             Europe  italian  English
# Japan               Asia      NaN  English
# ...

# %%
df
# Out:
#                 Population         GDP  Surface Area  Human DEvelopment Index  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                Continent      Lan Language
# Canada           America      NaN  English
# France            Europe   french  English
# Germany           Europe   german  English
# Italy             Europe  italian  English
# Japan               Asia      NaN  English
# ...

# %% [markdown]
# ### creating columns from other columns

# %%
df[['Population','GDP']]
# Out:
#                 Population         GDP
# Canada              35.467   1785387.0
# France              63.951   2833687.0
# Germany             80.940   3874437.0
# Italy               60.665   2167744.0
# Japan              127.061   4602367.0
# United Kingdom      64.511   2950039.0
# United states      318.523  17348075.0
# China              500.000         NaN

# %%
df['GDP']/ df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United states     54464.120330
# China                      NaN
# dtype: float64

# %%
df['GDP per capita']=df['GDP']/df['Population']
df
# Out:
#                 Population         GDP  Surface Area  Human DEvelopment Index  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                Continent      Lan Language  GDP per capita
# Canada           America      NaN  English    50339.385908
# France            Europe   french  English    44310.284437
# Germany           Europe   german  English    47868.013343
# ...

# %%
df.rename(columns=lambda x:x.upper())
# Out:
#                 POPULATION         GDP  SURFACE AREA  HUMAN DEVELOPMENT INDEX  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                CONTINENT      LAN LANGUAGE  GDP PER CAPITA
# Canada           America      NaN  English    50339.385908
# France            Europe   french  English    44310.284437
# Germany           Europe   german  English    47868.013343
# ...

# %%
df.rename(index=lambda x:x.upper())
# Out:
#                 Population         GDP  Surface Area  Human DEvelopment Index  \
# CANADA              35.467   1785387.0     9984670.0                    0.913
# FRANCE              63.951   2833687.0      640679.0                    0.888
# GERMANY             80.940   3874437.0      357114.0                    0.916
# ITALY               60.665   2167744.0      301336.0                    0.873
# JAPAN              127.061   4602367.0      377930.0                    0.891
# UNITED KINGDOM      64.511   2950039.0      242495.0                    0.907
# UNITED STATES      318.523  17348075.0     9525067.0                    0.915
# CHINA              500.000         NaN           NaN                    0.987
#
#                Continent      Lan Language  GDP per capita
# CANADA           America      NaN  English    50339.385908
# FRANCE            Europe   french  English    44310.284437
# GERMANY           Europe   german  English    47868.013343
# ...

# %% [markdown]
# ## statistical info for more data analysis

# %%
popu=df['Population'] # create a variable for population (popu)
popu
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# China             500.000
# Name: Population, dtype: float64

# %%
popu.min() # minimum value of population
# Out:
# np.float64(35.467)

# %%
popu.max()
# Out:
# np.float64(500.0)

# %%
popu.sum()
# Out:
# np.float64(1251.118)

# %%
popu.median()
# Out:
# np.float64(72.7255)

# %%
popu.std()
# Out:
# np.float64(165.47775053095722)

# %%
len(popu)
# Out:
# 8

# %%
popu.sum() / len(popu)
# Out:
# np.float64(156.38975)

# %%
popu.quantile(.25) # print 25% values
# Out:
# np.float64(63.1295)

# %%
popu.quantile([.2,.4,.6,.8,1])
# Out:
# 0.2     61.9794
# 0.4     64.3990
# 0.6     90.1642
# 0.8    241.9382
# 1.0    500.0000
# Name: Population, dtype: float64

# %%
df.to_csv('G7 counties.csv')
df
# Out:
#                 Population         GDP  Surface Area  Human DEvelopment Index  \
# Canada              35.467   1785387.0     9984670.0                    0.913
# France              63.951   2833687.0      640679.0                    0.888
# Germany             80.940   3874437.0      357114.0                    0.916
# Italy               60.665   2167744.0      301336.0                    0.873
# Japan              127.061   4602367.0      377930.0                    0.891
# United Kingdom      64.511   2950039.0      242495.0                    0.907
# United states      318.523  17348075.0     9525067.0                    0.915
# China              500.000         NaN           NaN                    0.987
#
#                Continent      Lan Language  GDP per capita
# Canada           America      NaN  English    50339.385908
# France            Europe   french  English    44310.284437
# Germany           Europe   german  English    47868.013343
# ...

# %%
new_data=pd.read_csv('G7 counties.csv')
new_data
# Out:
#        Unnamed: 0  Population         GDP  Surface Area  \
# 0          Canada      35.467   1785387.0     9984670.0
# 1          France      63.951   2833687.0      640679.0
# 2         Germany      80.940   3874437.0      357114.0
# 3           Italy      60.665   2167744.0      301336.0
# 4           Japan     127.061   4602367.0      377930.0
# 5  United Kingdom      64.511   2950039.0      242495.0
# 6   United states     318.523  17348075.0     9525067.0
# 7           China     500.000         NaN           NaN
#
#    Human DEvelopment Index Continent      Lan Language  GDP per capita
# 0                    0.913   America      NaN  English    50339.385908
# 1                    0.888    Europe   french  English    44310.284437
# 2                    0.916    Europe   german  English    47868.013343
# 3                    0.873    Europe  italian  English    35733.025633
# 4                    0.891      Asia      NaN  English    36221.712406
# ...

# %%
new_data.head(10)
# Out:
#        Unnamed: 0  Population         GDP  Surface Area  \
# 0          Canada      35.467   1785387.0     9984670.0
# 1          France      63.951   2833687.0      640679.0
# 2         Germany      80.940   3874437.0      357114.0
# 3           Italy      60.665   2167744.0      301336.0
# 4           Japan     127.061   4602367.0      377930.0
# 5  United Kingdom      64.511   2950039.0      242495.0
# 6   United states     318.523  17348075.0     9525067.0
# 7           China     500.000         NaN           NaN
#
#    Human DEvelopment Index Continent      Lan Language  GDP per capita
# 0                    0.913   America      NaN  English    50339.385908
# 1                    0.888    Europe   french  English    44310.284437
# 2                    0.916    Europe   german  English    47868.013343
# 3                    0.873    Europe  italian  English    35733.025633
# 4                    0.891      Asia      NaN  English    36221.712406
# ...
